# %% [markdown]
# <a href="https://colab.research.google.com/github/Azyur-i/CS182-03/blob/main/CO1SA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import pandas as pd
from IPython.display import Image, display

PROJECT_PATH = "/content/drive/MyDrive/yolo_runs"
DATA_YAML = "/content/drive/MyDrive/dataset/data.yaml"

# %%
model1 = YOLO("yolo26n.pt")

results1 = model1.train(
    data=DATA_YAML,
    epochs=25,
    imgsz=640,
    batch=4,
    optimizer="AdamW",
    lr0=0.01,
    name="model1",
    project=PROJECT_PATH
)
metrics1 = model1.val()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
model2 = YOLO("yolo26n.pt")

results2 = model2.train(
    data=DATA_YAML,
    epochs=30,
    imgsz=640,
    batch=-1,   # auto batch
    optimizer="SGD",
    lr0=0.001,
    name="model2",
    project=PROJECT_PATH
)

metrics2 = model2.val()
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model3 = YOLO("yolo26n.pt")

results3 = model3.train(
    data=DATA_YAML,
    epochs=40,
    imgsz=640,
    batch=4,
    optimizer="auto",
    lr0=0.0001,
    name="model3",
    project=PROJECT_PATH
)

metrics3 = model3.val()
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
data = {
    "Model": ["Model1", "Model2", "Model3"],
    "mAP50": [
        metrics1.box.map50,
        metrics2.box.map50,
        metrics3.box.map50
    ],
    "Precision": [
        metrics1.box.mp,
        metrics2.box.mp,
        metrics3.box.mp
    ],
    "Recall": [
        metrics1.box.mr,
        metrics2.box.mr,
        metrics3.box.mr
    ],
    "F1 Score": [
        metrics1.box.f1,
        metrics2.box.f1,
        metrics3.box.f1
    ]
}

df = pd.DataFrame(data)
df

print("Model 1 Confusion Matrix")
display(Image("/content/runs/detect/model12/confusion_matrix.png"))

# %%
print("Model 2 Confusion Matrix")
display(Image("/content/runs/detect/model2/confusion_matrix.png"))

# %%
print("Model 3 Confusion Matrix")
display(Image("/content/runs/detect/model3/confusion_matrix.png"))
